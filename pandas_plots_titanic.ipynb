# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
d = pd.read_csv('titanic_train.csv')

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.rcParams['figure.figsize'] = (10,7)

# %%
plt.plot(d.Age, '*-')
plt.title('Informações dos Passageiros', size=20)
plt.xlabel('ID do Passageiro', size=20)
plt.ylabel('Idade', size=20)
plt.show()

# %%
d.Age.plot()
plt.title('Informações dos Passageiros', size=20)
plt.xlabel('ID do Passageiro', size=20)
plt.ylabel('Idade', size=20)
plt.show()

# %%
d.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
d['Survived'].sum()
# Out:
# 342

# %%
d['Survived'] = np.where(d['Survived'] == 1, 'Yes', 'No')

# %%
colors = ['red', 'green']
fig = d['Survived'].value_counts().plot(kind='bar', color=colors)
plt.xlabel('Survived', size=20)
plt.savefig('survived.png')

# %%
pd.DataFrame(d[d['Survived'] == 'No'].Fare.describe())
# Out:
#              Fare
# count  549.000000
# mean    22.117887
# std     31.388207
# min      0.000000
# 25%      7.854200
# 50%     10.500000
# 75%     26.000000
# max    263.000000

# %%
pd.DataFrame(d[d['Survived'] == 'No'].Age.describe()).loc[['mean', 'min', 'max']]
# Out:
#             Age
# mean  30.626179
# min    1.000000
# max   74.000000

# %%
pd.DataFrame(d[d['Survived'] == 'Yes'].Age.describe()).loc[['mean', 'min', 'max']]
# Out:
#            Age
# mean  28.34369
# min    0.42000
# max   80.00000

# %%
pd.DataFrame(d.loc[(d['Survived'] == 'Yes') & (d['Sex'] == 'male')]['Age'].describe().loc[['mean', 'count', 'min', 'max']])
# Out:
#              Age
# mean   27.276022
# count  93.000000
# min     0.420000
# max    80.000000

# %%
d.loc[(d['Survived'] == 'No') & (d['Sex'] == 'male')][['Fare', 'Age']].describe().loc[['mean', 'count', 'min', 'max']]
# Out:
#              Fare         Age
# mean    21.960993   31.618056
# count  468.000000  360.000000
# min      0.000000    1.000000
# max    263.000000   74.000000

# %%
from pandas.core import describe
d.loc[(d['Survived'] == 'Yes') & (d['Sex'] == 'female')][['Fare', 'Age']].describe()
# Out:
#              Fare         Age
# count  233.000000  197.000000
# mean    51.938573   28.847716
# std     64.102256   14.175073
# min      7.225000    0.750000
# 25%     13.000000   19.000000
# 50%     26.000000   28.000000
# 75%     76.291700   38.000000
# max    512.329200   63.000000

# %%
d.loc[(d['Survived'] == 'No') & (d['Sex'] == 'female')][['Fare', 'Age']].describe().loc[['mean', 'count', 'min', 'max']]
# Out:
#              Fare        Age
# mean    23.024385  25.046875
# count   81.000000  64.000000
# min      6.750000   2.000000
# max    151.550000  57.000000

# %%
pd.DataFrame(d[['Sex', 'Survived']].value_counts())
# Out:
#                    0
# Sex    Survived
# male   No        468
# female Yes       233
# male   Yes       109
# female No         81

# %%
pd.DataFrame(d.loc[(d['Survived'] == 'Yes')]['Fare'].describe().loc[['mean', 'min', 'max']])
# Out:
#             Fare
# mean   48.395408
# min     0.000000
# max   512.329200

# %%
pd.DataFrame(d.loc[(d['Survived'] == 'No')]['Fare'].describe().loc[['mean', 'min', 'max']])
# Out:
#             Fare
# mean   22.117887
# min     0.000000
# max   263.000000

# %%
soma_pago = d.groupby(['Survived'])['Fare'].sum().sort_values(ascending=False)

# %%
d.groupby(['Survived'])['Fare'].sum().describe()
# Out:
# count        2.000000
# mean     14346.974650
# std       3117.286962
# min      12142.719900
# 25%      13244.847275
# 50%      14346.974650
# 75%      15449.102025
# max      16551.229400
# Name: Fare, dtype: float64

# %%
soma_pago
# Out:
# Survived
# Yes    16551.2294
# No     12142.7199
# Name: Fare, dtype: float64

# %%
p = 16551.2294 / 12142.7199
p -= 1
p *= 100
p
# Out:
# 36.30578269371099

# %%
plt.scatter(d.PassengerId, d.Age, color='g')
plt.show()

# %%
d.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
d.Age.hist()
# Out:
# <Axes: >
